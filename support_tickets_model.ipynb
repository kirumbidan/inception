# %%
import pandas as pd

# %%
df = pd.read_csv('Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv')

# %%
df.head(10)
# Out:
#    flags                                        instruction category  \
# 0      B   question about cancelling order {{Order Number}}    ORDER
# 1    BQZ  i have a question about cancelling oorder {{Or...    ORDER
# 2   BLQZ    i need help cancelling puchase {{Order Number}}    ORDER
# 3     BL         I need to cancel purchase {{Order Number}}    ORDER
# 4  BCELN  I cannot afford this order, cancel purchase {{...    ORDER
# 5     BI     can you help me cancel order {{Order Number}}?    ORDER
# 6   BCLN  I can no longer afford order {{Order Number}},...    ORDER
# 7     BL    I am trying to cancel purchase {{Order Number}}    ORDER
# 8     BL     I have got to cancel purchase {{Order Number}}    ORDER
# 9    BLQ    i need help canceling purchase {{Order Number}}    ORDER
#
#          intent                                           response
# 0  cancel_order  I've understood you have a question regarding ...
# 1  cancel_order  I've been informed that you have a question ab...
# 2  cancel_order  I can sense that you're seeking assistance wit...
# 3  cancel_order  I understood that you need assistance with can...
# 4  cancel_order  I'm sensitive to the fact that you're facing f...
# 5  cancel_order  Of course, I'm here to assist you in canceling...
# 6  cancel_order  I pick up what you're putting down that you're...
# 7  cancel_order  I've understood that you're seeking assistance...
# 8  cancel_order  I'm sensitive to the fact that you're seeking ...
# 9  cancel_order  I perceive that you're seeking assistance with...

# %%
print(df.shape)
df.describe()
# Out:
# (26872, 5)
#         flags                        instruction category         intent  \
# count   26872                              26872    26872          26872
# unique    394                              24635       11             27
# top        BL  do you ship to {{Delivery City}}?  ACCOUNT  check_invoice
# freq     5212                                  8     5986           1000
#
#                                                  response
# count                                               26872
# unique                                              26870
# top     Firstly, I truly understand how pivotal the {{...
# freq                                                    2

# %%
print(f"Category Unique Values: \n{df['category'].unique()}")
print(f"\n Intent Unique Values:\n{df['intent'].unique()}")
# Out:
# Category Unique Values:
# <StringArray>
# [       'ORDER',     'SHIPPING',       'CANCEL',      'INVOICE',
#       'PAYMENT',       'REFUND',     'FEEDBACK',      'CONTACT',
#       'ACCOUNT',     'DELIVERY', 'SUBSCRIPTION']
# Length: 11, dtype: str
#
#  Intent Unique Values:
# <StringArray>
# [            'cancel_order',             'change_order',
#   'change_shipping_address',   'check_cancellation_fee',
#             'check_invoice',    'check_payment_methods',
#       'check_refund_policy',                'complaint',
#  'contact_customer_service',      'contact_human_agent',
#            'create_account',           'delete_account',
#          'delivery_options',          'delivery_period',
#              'edit_account',              'get_invoice',
#                'get_refund',  'newsletter_subscription',
#             'payment_issue',              'place_order',
#          'recover_password',    'registration_problems',
#                    'review',  'set_up_shipping_address',
#            'switch_account',              'track_order',
#              'track_refund']
# Length: 27, dtype: str

# %%
df.loc[df['category'] == "CANCEL"]
# Out:
#       flags                                        instruction category  \
# 2968  BCLWZ  I can't ifnd the bloody termination charge, I ...   CANCEL
# 2969    BIL        what is the fee for canceling the contract?   CANCEL
# 2970   BILP               could I check the withdrawal charge?   CANCEL
# 2971    BLQ   i need help to see the early termination penalty   CANCEL
# 2972    BLQ          need assistance to see the withdrawal fee   CANCEL
# ...     ...                                                ...      ...
# 3913   BCLM  I have to see the early termination fees, help me   CANCEL
# 3914   BCLZ      I want to check the termination fee , help me   CANCEL
# 3915    BIL      can you help me to see the withdrawal charge?   CANCEL
# 3916   BLQZ          i have got to check the early exit pnalty   CANCEL
# 3917   BILM      can you help me see the cancellation charges?   CANCEL
#
#                       intent  \
# 2968  check_cancellation_fee
# 2969  check_cancellation_fee
# 2970  check_cancellation_fee
# 2971  check_cancellation_fee
# 2972  check_cancellation_fee
# ...                      ...
# 3913  check_cancellation_fee
# 3914  check_cancellation_fee
# 3915  check_cancellation_fee
# 3916  check_cancellation_fee
# 3917  check_cancellation_fee
#
#                                                response
# 2968  No worries! I'll assist you in finding the ter...
# 2969  To inquire about the cancellation fee for your...
# 2970  Positively! I can help you with the informatio...
# 2971  Absolutely! To view the early termination pena...
# 2972  Indeed! I'm here to help you with checking the...
# ...                                                 ...
# 3913  Sure, I can assist you with checking the early...
# 3914  Unquestionably! To check the termination fee f...
# 3915  For sure! To view the withdrawal charge, you c...
# 3916  I'll make it happen! I can assist you with ver...
# 3917  Absolutely! I'd be happy to assist you in veri...
#
# [950 rows x 5 columns]

# %% [markdown]
# *****USE instruction and category to predict intent*****

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
